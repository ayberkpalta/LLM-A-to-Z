# %%
# loading libraries
from tag_util import word_tag_model
from nltk.corpus import treebank
from nltk.tag import UnigramTagger

# initializing training and testing set    
train_data = treebank.tagged_sents()[:3000]
test_data = treebank.tagged_sents()[3000:]

# Initializing the model
model = word_tag_model(treebank.words(), 
                       treebank.tagged_words())

# Initializing the Unigram
tag = UnigramTagger(model = model)

print ("Accuracy : ", tag.evaluate(test_data))
# Out:
# Accuracy :  0.5593352039715087
# /var/folders/w7/93jgq1650wn24p1vgpgyhglm0000gn/T/ipykernel_64953/76850905.py:17: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print ("Accuracy : ", tag.evaluate(test_data))

# %%
from nltk.corpus import treebank
import nltk

nltk.download('treebank')

train_sents = treebank.tagged_sents()[:3000]
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
# Loading libraries
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger, DefaultTagger
from tag_util import backoff_tagger

default_tagger = DefaultTagger('NN')

likely_tagger = UnigramTagger(
        model = model, backoff = default_tagger)

tag = backoff_tagger(train_sents, [
        UnigramTagger, BigramTagger, 
        TrigramTagger], backoff = likely_tagger)
    
print ("Accuracy : ", tag.evaluate(test_data))
# Out:
# Accuracy :  0.8806388948845241
# /var/folders/w7/93jgq1650wn24p1vgpgyhglm0000gn/T/ipykernel_64953/2805953578.py:14: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print ("Accuracy : ", tag.evaluate(test_data))

# %%
# Loading libraries
from nltk.tag import UnigramTagger
from nltk.tag import DefaultTagger

default_tagger = DefaultTagger('NN')

tagger = backoff_tagger(train_sents, [
        UnigramTagger, BigramTagger,
        TrigramTagger], backoff = default_tagger)
    
likely_tag = UnigramTagger(model = model, backoff = tagger)

print ("Accuracy : ", likely_tag.evaluate(test_data))
# Out:
# Accuracy :  0.8817181092164904
# /var/folders/w7/93jgq1650wn24p1vgpgyhglm0000gn/T/ipykernel_64953/3961738958.py:13: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print ("Accuracy : ", likely_tag.evaluate(test_data))
