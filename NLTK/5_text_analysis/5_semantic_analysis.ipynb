# %% [markdown]
# WordNet in NLTK
# WordNet is like a smart English dictionary that groups words into sets of synonyms called synsets.

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('maxent_ne_chunker')
nltk.download('words')

from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize
from nltk import pos_tag, ne_chunk
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
df = pd.read_csv('training.1600000.processed.noemoticon.csv.zip',
                 encoding='latin-1',
                 names=['target', 'ids', 'date', 'flag', 'user', 'text'])
df.head(3)
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...

# %%
tweet = df['text'][0]
print(f"Tweet: {tweet}")
# Out:
# Tweet: @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng') # pos tagger
tokens = word_tokenize(tweet)
tags = pos_tag(tokens)

print("Tokens:", tokens)
print("POS Tags:", tags)
# Out:
# Tokens: ['@', 'switchfoot', 'http', ':', '//twitpic.com/2y1zl', '-', 'Awww', ',', 'that', "'s", 'a', 'bummer', '.', 'You', 'shoulda', 'got', 'David', 'Carr', 'of', 'Third', 'Day', 'to', 'do', 'it', '.', ';', 'D']
# POS Tags: [('@', 'JJ'), ('switchfoot', 'NN'), ('http', 'NN'), (':', ':'), ('//twitpic.com/2y1zl', 'JJ'), ('-', ':'), ('Awww', 'NN'), (',', ','), ('that', 'WDT'), ("'s", 'VBZ'), ('a', 'DT'), ('bummer', 'NN'), ('.', '.'), ('You', 'PRP'), ('shoulda', 'VBP'), ('got', 'VBD'), ('David', 'NNP'), ('Carr', 'NNP'), ('of', 'IN'), ('Third', 'NNP'), ('Day', 'NNP'), ('to', 'TO'), ('do', 'VB'), ('it', 'PRP'), ('.', '.'), (';', ':'), ('D', 'NNP')]
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Step 5: Perform Word Sense Disambiguation (WSD)

# %%
sentence = "He went to the bank to deposit money."
tokens = word_tokenize(sentence)
sense = lesk(tokens, 'bank')
print("Best sense:", sense)
print("Definition:", sense.definition())
# Out:
# Best sense: Synset('depository_financial_institution.n.01')
# Definition: a financial institution that accepts deposits and channels the money into lending activities

# %% [markdown]
# Step 6: Calculate Semantic Similarity Between Words

# %%
dog = wn.synsets('good', pos=wn.ADJ)[0]
bad = wn.synsets('bad', pos=wn.ADJ)[0]

similarity = dog.wup_similarity(bad)
print(f"Semantic Similarity (Wu-Palmer): {similarity}")
# Out:
# Semantic Similarity (Wu-Palmer): 0.5

# %% [markdown]
# NER

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
tree = ne_chunk(tags)
print(tree)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /Users/ayberkpalta/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# (S
#   @/JJ
#   switchfoot/NN
#   http/NN
#   :/:
#   //twitpic.com/2y1zl/JJ
#   -/:
#   (GPE Awww/NN)
#   ,/,
#   that/WDT
#   's/VBZ
#   a/DT
#   bummer/NN
#   ./.
#   You/PRP
#   shoulda/VBP
#   got/VBD
#   (PERSON David/NNP Carr/NNP)
#   of/IN
#   (PERSON Third/NNP)
#   Day/NNP
#   to/TO
#   do/VB
#   it/PRP
#   ./.
#   ;/:
#   D/NNP)

# %%
def semantic_analysis(text):
    tokens = word_tokenize(text)
    tags = pos_tag(tokens)
    print("Original:", text)
    print("Tokens:", tokens)
    print("NER Tree:", ne_chunk(tags))

    for word in tokens:
        synsets = wn.synsets(word)
        if synsets:
            print(f"\nWord: {word}")
            for syn in synsets:
                print(f"  - {syn.name()}: {syn.definition()}")
    print("\n")

for i in range(2):
    semantic_analysis(df['text'][i])
# Out:
# Original: @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# Tokens: ['@', 'switchfoot', 'http', ':', '//twitpic.com/2y1zl', '-', 'Awww', ',', 'that', "'s", 'a', 'bummer', '.', 'You', 'shoulda', 'got', 'David', 'Carr', 'of', 'Third', 'Day', 'to', 'do', 'it', '.', ';', 'D']
# NER Tree: (S
#   @/JJ
#   switchfoot/NN
#   http/NN
#   :/:
#   //twitpic.com/2y1zl/JJ
#   -/:
#   (GPE Awww/NN)
#   ,/,
#   that/WDT
#   's/VBZ
#   a/DT
#   bummer/NN
#   ./.
#   You/PRP
#   shoulda/VBP
#   got/VBD
#   (PERSON David/NNP Carr/NNP)
#   of/IN
#   (PERSON Third/NNP)
#   Day/NNP
#   to/TO
#   do/VB
#   it/PRP
#   ./.
#   ;/:
#   D/NNP)
#
# Word: http
#   - hypertext_transfer_protocol.n.01: a protocol (utilizing TCP) to transfer hypertext requests and information between servers and browsers
#
# Word: a
#   - angstrom.n.01: a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
#   - vitamin_a.n.01: any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
#   - deoxyadenosine_monophosphate.n.01: one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
#   - adenine.n.01: (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
#   - ampere.n.02: the basic unit of electric current adopted under the Systeme International d'Unites
#   - a.n.06: the 1st letter of the Roman alphabet
#   - a.n.07: the blood group whose red cells carry the A antigen
#
# Word: bummer
#   - bummer.n.01: an experience that is irritating or frustrating or disappointing
#   - bummer.n.02: a bad reaction to a hallucinogenic drug
#
# Word: got
#   - get.v.01: come into the possession of something concrete or abstract
#   - become.v.01: enter or assume a certain state or condition
#   - get.v.03: cause to move; cause to be in a certain position or condition
#   - receive.v.02: receive a specified treatment (abstract)
#   - arrive.v.01: reach a destination; arrive by movement or progress
#   - bring.v.04: go or come after and bring or take back
#   - experience.v.03: go through (mental or physical states or experiences)
#   - pay_back.v.02: take vengeance on or get even
#   - have.v.17: achieve a point or goal
#   - induce.v.02: cause to do; cause to act in a specified manner
#   - get.v.11: succeed in catching or seizing, especially after a chase
#   - grow.v.08: come to have or undergo a change of (physical features and attributes)
#   - contract.v.04: be stricken by an illness, fall victim to an illness
#   - get.v.14: communicate with a place or person; establish communication with, as if by telephone
#   - make.v.02: give certain properties to something
#   - drive.v.11: move into a desired direction of discourse
#   - catch.v.18: grasp with the mind or develop an understanding of
#   - catch.v.07: attract and fix
#   - get.v.19: reach with a blow or hit in a particular spot
#   - get.v.20: reach by calculation
#   - get.v.21: acquire as a result of some effort or action
#   - get.v.22: purchase
#   - catch.v.21: perceive by hearing
#   - catch.v.22: suffer from the receipt of
#   - get.v.25: receive as a retribution or punishment
#   - scram.v.01: leave immediately; used usually in the imperative form
#   - get.v.27: reach and board
#   - get.v.28: irritate
#   - get.v.29: evoke an emotional response
#   - catch.v.24: apprehend and reproduce accurately
#   - draw.v.15: earn or achieve a base by being walked by the pitcher
#   - get.v.32: overcome or destroy
#   - perplex.v.01: be a mystery or bewildering to
#   - get_down.v.07: take the first step or steps in carrying out an action
#   - suffer.v.02: undergo (as of injuries and illnesses)
#   - beget.v.01: make children
#
# Word: David
#   - david.n.01: patron saint of Wales (circa 520-600)
#   - david.n.02: French neoclassical painter who actively supported the French Revolution (1748-1825)
#   - david.n.03: (Old Testament) the 2nd king of the Israelites; as a young shepherd he fought Goliath (a giant Philistine warrior) and killed him by hitting him in the head with a stone flung from a sling; he united Israel with Jerusalem as its capital; many of the Psalms are attributed to David (circa 1000-962 BC)
#
# Word: Third
#   - one-third.n.01: one of three equal parts of a divisible whole
#   - third_base.n.02: the fielding position of the player on a baseball team who is stationed near the third of the bases in the infield (counting counterclockwise from home plate)
#   - third.n.03: following the second position in an ordering or series
#   - third.n.04: the musical interval between one note and another three notes away from it
#   - third_gear.n.01: the third from the lowest forward ratio gear in the gear box of a motor vehicle
#   - third_base.n.01: the base that must be touched third by a base runner in baseball
#   - third.s.01: coming next after the second and just before the fourth in position
#   - third.r.01: in the third place
#
# Word: Day
#   - day.n.01: time for Earth to make a complete rotation on its axis
#   - day.n.02: some point or period in time
#   - day.n.03: a day assigned to a particular purpose or observance
#   - day.n.04: the time after sunrise and before sunset while it is light outside
#   - day.n.05: the recurring hours when you are not sleeping (especially those when you are working)
#   - day.n.06: an era of existence or influence
#   - day.n.07: the period of time taken by a particular planet (e.g. Mars) to make a complete rotation on its axis
#   - sidereal_day.n.01: the time for one complete rotation of the earth relative to a particular star, about 4 minutes shorter than a mean solar day
#   - day.n.09: a period of opportunity
#   - day.n.10: United States writer best known for his autobiographical works (1874-1935)
#
# Word: do
#   - bash.n.02: an uproarious party
#   - do.n.02: the syllable naming the first (tonic) note of any major scale in solmization
#   - doctor_of_osteopathy.n.01: doctor's degree in osteopathy
#   - make.v.01: engage in
#   - perform.v.01: carry out or perform an action
#   - do.v.03: get (something) done
#   - do.v.04: proceed or get along
#   - cause.v.01: give rise to; cause to happen or occur, not always intentionally
#   - practice.v.01: carry out or practice; as of jobs and professions
#   - suffice.v.01: be sufficient; be adequate, either in quality or quantity
#   - do.v.08: create or design, often in a certain way
#   - act.v.02: behave in a certain manner; show a certain behavior; conduct or comport oneself
#   - serve.v.09: spend time in prison or in a labor camp
#   - do.v.11: carry on or function
#   - dress.v.16: arrange attractively
#   - do.v.13: travel or traverse (a distance)
#
# Word: it
#   - information_technology.n.01: the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
#
# Word: D
#   - vitamin_d.n.01: a fat-soluble vitamin that prevents rickets
#   - five_hundred.n.01: the cardinal number that is the product of one hundred and five
#   - d.n.03: the 4th letter of the Roman alphabet
#   - five_hundred.s.01: denoting a quantity consisting of 500 items or units
#
#
# Original: is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# Tokens: ['is', 'upset', 'that', 'he', 'ca', "n't", 'update', 'his', 'Facebook', 'by', 'texting', 'it', '...', 'and', 'might', 'cry', 'as', 'a', 'result', 'School', 'today', 'also', '.', 'Blah', '!']
# NER Tree: (S
#   is/VBZ
#   upset/JJ
#   that/IN
#   he/PRP
#   ca/MD
#   n't/RB
#   update/VB
#   his/PRP$
#   Facebook/NNP
#   by/IN
#   texting/VBG
#   it/PRP
#   .../:
#   and/CC
#   might/MD
#   cry/VB
#   as/IN
#   a/DT
#   result/NN
#   (PERSON School/NNP)
#   today/NN
#   also/RB
#   ./.
#   Blah/UH
#   !/.)
#
# Word: is
#   - be.v.01: have the quality of being; (copula, used with an adjective or a predicate noun)
#   - be.v.02: be identical to; be someone or something
#   - be.v.03: occupy a certain position or area; be somewhere
#   - exist.v.01: have an existence, be extant
#   - be.v.05: happen, occur, take place
#   - equal.v.01: be identical or equivalent to
#   - constitute.v.01: form or compose
#   - be.v.08: work in a specific place, with a specific subject, or in a specific function
#   - embody.v.02: represent, as of a character on stage
#   - be.v.10: spend or use time
#   - be.v.11: have life, be alive
#   - be.v.12: to remain unmolested, undisturbed, or uninterrupted -- used only in infinitive form
#   - cost.v.01: be priced at
#
# Word: upset
#   - disturbance.n.02: an unhappy and worried mental state
#   - upset.n.02: the act of disturbing the mind or body
#   - disorder.n.01: a physical condition in which there is a disturbance of normal functioning
#   - upset.n.04: a tool used to thicken or spread metal (the end of a bar or a rivet etc.) by forging or hammering or swaging
#   - upset.n.05: the act of upsetting something
#   - overturn.n.02: an improbable and unexpected victory
#   - upset.v.01: disturb the balance or stability of
#   - upset.v.02: cause to lose one's composure
#   - disturb.v.01: move deeply
#   - overturn.v.02: cause to overturn from an upright or normal position
#   - swage.v.01: form metals with a swage
#   - upset.v.06: defeat suddenly and unexpectedly
#   - disquieted.s.01: afflicted with or marked by anxious uneasiness or trouble or grief
#   - broken.s.05: thrown into a state of disarray or confusion
#   - upset.s.03: used of an unexpected defeat of a team favored to win
#   - upset.s.04: mildly physically distressed
#   - overturned.s.01: having been turned so that the bottom is no longer the bottom
#
# Word: he
#   - helium.n.01: a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas)
#   - he.n.02: the 5th letter of the Hebrew alphabet
#
# Word: ca
#   - calcium.n.01: a white metallic element that burns with a brilliant light; the fifth most abundant element in the earth's crust; an important component of most plants and animals
#   - california.n.01: a state in the western United States on the Pacific; the 3rd largest state; known for earthquakes
#
# Word: update
#   - update.n.01: news that updates your information
#   - update.v.01: modernize or bring up to date
#   - update.v.02: bring up to date; supply with recent information
#   - update.v.03: bring to the latest state of technology
#
# Word: by
#   - by.r.01: so as to pass a given point
#   - aside.r.06: in reserve; not for immediate use
#
# Word: it
#   - information_technology.n.01: the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
#
# Word: might
#   - might.n.01: physical strength
#
# Word: cry
#   - cry.n.01: a loud utterance; often in protest or opposition
#   - cry.n.02: a loud utterance of emotion (especially when inarticulate)
#   - war_cry.n.01: a slogan used to rally support for a cause
#   - cry.n.04: a fit of weeping
#   - cry.n.05: the characteristic utterance of an animal
#   - shout.v.02: utter a sudden loud cry
#   - cry.v.02: shed tears because of sadness, rage, or pain
#   - exclaim.v.01: utter aloud; often with surprise, horror, or joy
#   - cry.v.04: proclaim or announce in public
#   - cry.v.05: demand immediate action
#   - cry.v.06: utter a characteristic sound
#   - cry.v.07: bring into a particular state by crying
#
# Word: as
#   - arsenic.n.02: a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar
#   - american_samoa.n.01: a United States territory on the eastern part of the island of Samoa
#   - angstrom.n.01: a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
#   - vitamin_a.n.01: any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
#   - deoxyadenosine_monophosphate.n.01: one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
#   - adenine.n.01: (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
#   - ampere.n.02: the basic unit of electric current adopted under the Systeme International d'Unites
#   - a.n.06: the 1st letter of the Roman alphabet
#   - a.n.07: the blood group whose red cells carry the A antigen
#   - equally.r.01: to the same degree (often followed by `as')
#
# Word: a
#   - angstrom.n.01: a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
#   - vitamin_a.n.01: any of several fat-soluble vitamins essential for normal vision; prevents night blindness or inflammation or dryness of the eyes
#   - deoxyadenosine_monophosphate.n.01: one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
#   - adenine.n.01: (biochemistry) purine base found in DNA and RNA; pairs with thymine in DNA and with uracil in RNA
#   - ampere.n.02: the basic unit of electric current adopted under the Systeme International d'Unites
#   - a.n.06: the 1st letter of the Roman alphabet
#   - a.n.07: the blood group whose red cells carry the A antigen
#
# Word: result
#   - consequence.n.01: a phenomenon that follows and is caused by some previous phenomenon
#   - solution.n.02: a statement that solves a problem or explains how to solve the problem
#   - result.n.03: something that results
#   - resultant_role.n.01: the semantic role of the noun phrase whose referent exists only by virtue of the activity denoted by the verb in the clause
#   - result.v.01: issue or terminate (in a specified way, state, etc.); end
#   - leave.v.07: have as a result or residue
#   - result.v.03: come about or follow as a consequence
#
# Word: School
#   - school.n.01: an educational institution
#   - school.n.02: a building where young people receive education
#   - school.n.03: the process of being formally educated at a school
#   - school.n.04: a body of creative artists or writers or thinkers linked by a similar style or by similar teachers
#   - school.n.05: the period of instruction in a school; the time period when school is in session
#   - school.n.06: an educational institution's faculty and students
#   - school.n.07: a large group of fish
#   - school.v.01: educate in or as if in a school
#   - educate.v.03: teach or refine to be discriminative in taste or judgment
#   - school.v.03: swim in or form a large group of fish
#
# Word: today
#   - today.n.01: the present time or age
#   - today.n.02: the day that includes the present moment (as opposed to yesterday or tomorrow)
#   - nowadays.r.01: in these times; - Nancy Mitford
#   - today.r.02: on this day as distinct from yesterday or tomorrow
#
# Word: also
#   - besides.r.02: in addition
#
# Word: Blah
#   - bombast.n.01: pompous or pretentious talk or writing

# %%
from nltk.corpus import wordnet as wn

def semantic_analysis_word(word):
    synsets = wn.synsets(word)
    if synsets:
        print(f"Word: {word}")
        for syn in synsets:
            print(f"  - {syn.name()}: {syn.definition()}")
    else:
        print(f"'{word}' kelimesi WordNet sözlüğünde bulunamadı.")

# Sadece "Day" kelimesi için çalıştırıyoruz
semantic_analysis_word("Day")
# Out:
# Word: Day
#   - day.n.01: time for Earth to make a complete rotation on its axis
#   - day.n.02: some point or period in time
#   - day.n.03: a day assigned to a particular purpose or observance
#   - day.n.04: the time after sunrise and before sunset while it is light outside
#   - day.n.05: the recurring hours when you are not sleeping (especially those when you are working)
#   - day.n.06: an era of existence or influence
#   - day.n.07: the period of time taken by a particular planet (e.g. Mars) to make a complete rotation on its axis
#   - sidereal_day.n.01: the time for one complete rotation of the earth relative to a particular star, about 4 minutes shorter than a mean solar day
#   - day.n.09: a period of opportunity
#   - day.n.10: United States writer best known for his autobiographical works (1874-1935)
