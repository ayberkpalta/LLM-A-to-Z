# %%
from nltk import word_tokenize, sent_tokenize

# %%
sent = "I am a New Grad AI engineer. This is my NLTK projects "
print(word_tokenize(sent))
print(sent_tokenize(sent))
# Out:
# ['I', 'am', 'a', 'New', 'Grad', 'AI', 'engineer', '.', 'This', 'is', 'my', 'NLTK', 'projects']
# ['I am a New Grad AI engineer.', 'This is my NLTK projects']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

porter = PorterStemmer()
print(porter.stem("play"))
print(porter.stem("playing"))
print(porter.stem("plays"))
print(porter.stem("played"))
print(porter.stem("player"))
# Out:
# play
# play
# play
# play
# player

# %%
porter = PorterStemmer()
print(porter.stem("Communication"))
# Out:
# commun

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("plays", 'v')) # v-> verb
print(lemmatizer.lemmatize("played", 'v'))
print(lemmatizer.lemmatize("play", 'v'))
print(lemmatizer.lemmatize("playing", 'v'))
print(lemmatizer.lemmatize("player","v"))
# Out:
# play
# play
# play
# play
# player

# %%
print(lemmatizer.lemmatize("Communication", 'v'))
# Out:
# Communication
