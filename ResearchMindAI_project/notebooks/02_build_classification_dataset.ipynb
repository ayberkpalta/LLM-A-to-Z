# %%
categories = {
    "cs.CL": "NLP",
    "cs.CV": "Computer Vision",
    "cs.LG": "Machine Learning",
    "cs.RO": "Robotics"
}

print(categories)
# Out:
# {'cs.CL': 'NLP', 'cs.CV': 'Computer Vision', 'cs.LG': 'Machine Learning', 'cs.RO': 'Robotics'}
